# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\mohd abdul khaleq b\\Downloads\\mymoviedb.csv", lineterminator='\n')

# %%
df.head(2)
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
#
#                                           Poster_Url
# 0  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 1  https://image.tmdb.org/t/p/original/74xTEgt7R3...

# %%
df.shape
# Out:
# (9827, 9)

# %% [markdown]
# 9827 rows and 9 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %% [markdown]
# No null values in the data

# %%
df['Original_Language'].unique()
# Out:
# array(['en', 'ja', 'fr', 'hi', 'es', 'ru', 'de', 'th', 'ko', 'tr', 'cn',
#        'zh', 'it', 'pt', 'ml', 'pl', 'fi', 'no', 'da', 'id', 'sv', 'nl',
#        'te', 'sr', 'is', 'ro', 'tl', 'fa', 'uk', 'nb', 'eu', 'lv', 'ar',
#        'el', 'cs', 'ms', 'bn', 'ca', 'la', 'ta', 'hu', 'he', 'et'],
#       dtype=object)

# %%
df.groupby('Original_Language')['Original_Language'].count()
# Out:
# Original_Language
# ar       2
# bn       1
# ca       1
# cn     109
# cs       4
# da      28
# de      82
# el       5
# en    7570
# es     339
# et       1
# eu       1
# fa       3
# fi       5
# fr     292
# he       2
# hi      26
# hu       3
# id      15
# is       2
# it     123
# ja     645
# ko     170
# la       1
# lv       1
# ml       1
# ms       1
# nb       1
# nl      21
# no      26
# pl      17
# pt      37
# ro       2
# ru      83
# sr       5
# sv      23
# ta       2
# te       6
# th      17
# tl       8
# tr      15
# uk       2
# zh     129
# Name: Original_Language, dtype: int64

# %%
df['Genre'].unique()
# Out:
# array(['Action, Adventure, Science Fiction', 'Crime, Mystery, Thriller',
#        'Thriller', ..., 'Comedy, TV Movie, Romance',
#        'Science Fiction, Fantasy, Family, Music',
#        'War, Drama, Science Fiction'], shape=(2337,), dtype=object)

# %%
df.groupby('Genre')['Genre'].count()
# Out:
# Genre
# Action                                          99
# Action, Adventure                               24
# Action, Adventure, Animation                     6
# Action, Adventure, Animation, Comedy             1
# Action, Adventure, Animation, Comedy, Family     3
#                                                 ..
# Western, Drama, Mystery                          1
# Western, History                                 1
# Western, Horror                                  2
# Western, Mystery, Thriller, Drama                1
# Western, Thriller                                2
# Name: Genre, Length: 2337, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate movies in the list( Not repeated)

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9827.000000   9827.000000
# mean     40.326088   1392.805536      6.439534
# std     108.873998   2611.206907      1.129759
# min      13.354000      0.000000      0.000000
# 25%      16.128500    146.000000      5.900000
# 50%      21.199000    444.000000      6.500000
# 75%      35.191500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
df['Release_Date']= pd.to_datetime(df['Release_Date'])

# %%
df['Release_Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   datetime64[ns]
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 691.1+ KB

# %%
df['Release_Date']=df['Release_Date'].dt.year

# %%
df.head(2)
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
#
#                                           Poster_Url
# 0  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 1  https://image.tmdb.org/t/p/original/74xTEgt7R3...

# %%
df1=df.drop(["Overview", "Original_Language", "Poster_Url"], axis=1, inplace =True)

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
#
#    Vote_Average                               Genre
# 0           8.3  Action, Adventure, Science Fiction
# 1           8.1            Crime, Mystery, Thriller
# 2           6.3                            Thriller
# 3           7.7  Animation, Comedy, Family, Fantasy
# 4           7.0    Action, Adventure, Thriller, War

# %%
df.isna().sum()
# Out:
# Release_Date    0
# Title           0
# Popularity      0
# Vote_Count      0
# Vote_Average    0
# Genre           0
# dtype: int64

# %% [markdown]
# Split genres

# %%
df['Genre']=df['Genre'].str.split(', ')

df= df.explode('Genre').reset_index(drop=True)
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
# 3          2022               The Batman    3827.658        1151
# 4          2022               The Batman    3827.658        1151
#
#    Vote_Average            Genre
# 0           8.3           Action
# 1           8.3        Adventure
# 2           8.3  Science Fiction
# 3           8.1            Crime
# 4           8.1          Mystery

# %%
df["Genre"]=df["Genre"].astype('category')

# %%
df['Genre'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=object)

# %%
df.shape
# Out:
# (25793, 6)

# %%
df.nunique()
# Out:
# Release_Date     102
# Title           9513
# Popularity      8160
# Vote_Count      3266
# Vote_Average      74
# Genre             19
# dtype: int64

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
# 3          2022               The Batman    3827.658        1151
# 4          2022               The Batman    3827.658        1151
#
#    Vote_Average            Genre
# 0           8.3           Action
# 1           8.3        Adventure
# 2           8.3  Science Fiction
# 3           8.1            Crime
# 4           8.1          Mystery

# %%
df['Genre'].nunique()
# Out:
# 19

# %% [markdown]
# 19 genres in total

# %% [markdown]
# ***Most Frequent Genre***

# %%
most_frequent_genre = df['Genre'].value_counts() .idxmax()
print("Most frequent genre:", most_frequent_genre)
# Out:
# Most frequent genre: Drama

# %%
genre_counts = df['Genre'].value_counts()

sns.barplot(x=genre_counts.values, y=genre_counts.index)

plt.title('Genres')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ***Heighest Popularity***

# %%
df[df['Popularity'] == df['Popularity'].max()]
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
#
#    Vote_Average            Genre
# 0           8.3           Action
# 1           8.3        Adventure
# 2           8.3  Science Fiction

# %% [markdown]
# ***Lowest Popularity***

# %%
df[df['Popularity'] == df['Popularity'].min()]
# Out:
#        Release_Date                                 Title  Popularity  \
# 25787          2021  The United States vs. Billie Holiday      13.354
# 25788          2021  The United States vs. Billie Holiday      13.354
# 25789          2021  The United States vs. Billie Holiday      13.354
# 25790          1984                               Threads      13.354
# 25791          1984                               Threads      13.354
# 25792          1984                               Threads      13.354
#
#        Vote_Count  Vote_Average            Genre
# 25787         152           6.7            Music
# 25788         152           6.7            Drama
# 25789         152           6.7          History
# 25790         186           7.8              War
# 25791         186           7.8            Drama
# 25792         186           7.8  Science Fiction

# %% [markdown]
# *Heighest Vote Average*

# %%
df[df['Vote_Average'] == df['Vote_Average'].max()]
# Out:
#        Release_Date                       Title  Popularity  Vote_Count  \
# 24756          2020  Kung Fu Master Huo Yuanjia      13.745           1
# 24757          2020  Kung Fu Master Huo Yuanjia      13.745           1
#
#        Vote_Average   Genre
# 24756          10.0  Action
# 24757          10.0   Drama

# %% [markdown]
# *This movie has Heighest Vote Average but there is only 1 vote*

# %%
movies_2024 = df[df['Release_Date'] == 2024]


print(movies_2024)
# Out:
#       Release_Date            Title  Popularity  Vote_Count  Vote_Average  \
# 9137          2024  Despicable Me 4      27.987           0           0.0
# 9138          2024  Despicable Me 4      27.987           0           0.0
# 9139          2024  Despicable Me 4      27.987           0           0.0
# 9140          2024  Despicable Me 4      27.987           0           0.0
#
#           Genre
# 9137  Animation
# 9138     Family
# 9139     Comedy
# 9140  Adventure

# %% [markdown]
# *Movies released in 2024*

# %%
movies_2022 = df[df['Release_Date'] == 2022]

print(movies_2022)      
print(movies_2022.count())
# Out:
#        Release_Date                                    Title  Popularity  \
# 3              2022                               The Batman    3827.658
# 4              2022                               The Batman    3827.658
# 5              2022                               The Batman    3827.658
# 6              2022                                  No Exit    2618.087
# 15             2022                             The Commando    1750.484
# ...             ...                                      ...         ...
# 25133          2022  Chickenhare and the Hamster of Darkness      13.590
# 25434          2022                                    Ted K      13.479
# 25435          2022                                    Ted K      13.479
# 25436          2022                                    Ted K      13.479
# 25507          2022     Tony Hawk: Until the Wheels Fall Off      13.446
#
#        Vote_Count  Vote_Average        Genre  Year
# ...

# %%
year_counts = df['Year'].value_counts().sort_index()
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()
